# %%
import matplotlib.pyplot as plt
import numpy as np
import json
from config import large_figure_width, standard_figure_width

g = 9.81

W = 54
w = 54
T = 3
B = 5.7
h = 4.5
Ac = h*W
Ab = B*T
Hm = Ac/W
m = Ab/Ac
p = (W-w)/2/h

z = np.linspace(0, .8, 100)

z = z/Hm

Fc = np.sqrt( ( 2*z*(1-z-m)**2 )/( 1-(1-z-m)**2 ) )

standard_figure_height = 0.7 * standard_figure_width
fig_size = (standard_figure_width, standard_figure_height)

plt.figure(figsize=fig_size)

plt.plot( Fc, z, label='Constantine' )
plt.xlabel( r'Fr' )
plt.ylabel( r'$\dfrac{z}{h}$' )


plt.legend()
plt.savefig('../Figures/Constantine.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Constantine trapeze

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
from config import large_figure_width, standard_figure_width

g = 9.81

W = 54
w = 36
T = 3
B = 5.7
h = 4.5
Ac = h*W
Ab = B*T
Hm = Ac/W
m = Ab/Ac
p = (W-w)/2/h

z = np.linspace(0, .8, 100)

z = z/Hm

Fct = np.sqrt( ( 2*z*(1-z-m+p*Hm/W*z**2)**2 )/( 1-(1-z-m+p*Hm/W*z**2)**2 ) )
standard_figure_height = 0.7 * standard_figure_width
fig_size = (standard_figure_width, standard_figure_height)

plt.figure(figsize=fig_size)

plt.plot( Fct, z, label='Constantine trapeze' )
plt.xlabel( r'Fr' )
plt.ylabel( r'$\dfrac{z}{h}$' )


plt.legend()
plt.savefig('../Figures/Constantine_trapeze.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Constantine demi-circulaire

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
from config import large_figure_width, standard_figure_width

g = 9.81

W = 40

T = 3
B = 5.7

Ac = np.pi*(W/2)**2
Ab = B*T
Hm = Ac/W
m = Ab/Ac


z0 = np.linspace(0, 1, 100)

p = W/2/z0*( 1 - 1/(np.sqrt( 1 + (2*z/W)**2 )) )


Ar = W/2*( z0 -W/2*np.arcsinh(2*z0/W) )
# Ar = (2 * z0 - z0 * np.sqrt(1 - z0**2) - np.arcsin(z0))
# Ar = -p*z0**2/2
Aw = Ac - Ab - z*W + 2*Ar


z = z0/Hm

Fcc = np.sqrt(2 * z * (Aw/Ac)**2 / (1 - (Aw/Ac)**2))

Fcca = np.sqrt( ( 2*z*(1-z-m+p*Hm/W*z**2)**2 )/( 1-(1-z-m+p*Hm/W*z**2)**2 ) )

# Fcc = np.sqrt(2 * z * (1 - z - m + Aw/Ac)**2 / 1 - (1 - z - m + Aw/Ac)**2)


standard_figure_height = 0.7 * standard_figure_width
fig_size = (standard_figure_width, standard_figure_height)

plt.figure(figsize=fig_size)
plt.plot( Fcc, z, label='Constantine demi-circulaire' )
plt.plot( Fcca, z, '--', label='Constantine demi-circulaire approché' )
plt.xlabel( r'Fr' )
plt.ylabel( r'$\dfrac{z}{h}$' )


plt.legend()
plt.savefig('../Figures/Constantine_demi-circulaire.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_34574/4138024811.py:21: RuntimeWarning: divide by zero encountered in divide
#   p = W/2/z0*( 1 - 1/(np.sqrt( 1 + (2*z/W)**2 )) )
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_34574/4138024811.py:21: RuntimeWarning: invalid value encountered in multiply
#   p = W/2/z0*( 1 - 1/(np.sqrt( 1 + (2*z/W)**2 )) )
