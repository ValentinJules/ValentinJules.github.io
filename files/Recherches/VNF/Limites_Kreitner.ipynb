# %%
import numpy as np
import matplotlib.pyplot as plt
from config import large_figure_width, standard_figure_width

m = 0.1
F = np.linspace(0, 1, 1000)


q = 2/F**2
p = -( 1+q*(1-m) )
y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

uschijf = y -1
F_filtered = F[~np.isnan(uschijf)]
uschijf_filtered = uschijf[~np.isnan(uschijf)]


ustar_0 = m/( 1 - m -F_filtered**2 )
ustar_1 = m +0*F_filtered
ustar_2 = m/( 1 - F_filtered**2 ) 
ustar_3 = m/( 1 - m ) +0*F_filtered
ustar_4 = m + F_filtered**2
ustar_5 = m - m +F_filtered**2


standard_figure_height = 0.7 * standard_figure_width
fig_size = (standard_figure_width, standard_figure_height)

plt.figure()


plt.plot( F_filtered, uschijf_filtered, label='Kreitner', lw = 3, color = 'black' )
plt.plot( F_filtered, ustar_0, label = r'$ \dfrac{m}{1-m -F^2} $'  )
plt.plot( F_filtered, ustar_2, label = r'$ \dfrac{m}{1-F^2} $'  )
plt.plot( F_filtered, ustar_3, label = r'$ \dfrac{m}{1-m} $'  )
plt.plot( F_filtered, ustar_1, label = r'$ m $'  )
# plt.plot( F_filtered, ustar_4, label = r'$ m+F^2 $'  )
# plt.plot( F_filtered, ustar_5, label = r'$ m-m^2 +F^2 $'  )




plt.xlabel( r'Fr' )
plt.ylabel( r'$\dfrac{U}{V}$' )

plt.ylim(0, 0.4)
plt.legend()
plt.title( f'm = {np.round(m, 3)}' )
plt.savefig('../figures/limites_kreitner-u-F.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2478521152.py:9: RuntimeWarning: divide by zero encountered in divide
#   q = 2/F**2
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2478521152.py:11: RuntimeWarning: invalid value encountered in divide
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2478521152.py:11: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

# %%
import numpy as np
import matplotlib.pyplot as plt
from config import large_figure_width, standard_figure_width

m = 0.1
F = np.linspace(0, 1, 1000)


q = 2/F**2
p = -( 1+q*(1-m) )
y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

uschijf = y -1
F_filtered = F[~np.isnan(uschijf)]
uschijf_filtered = uschijf[~np.isnan(uschijf)]


ustar_0 = m/( 1 - m -F_filtered**2 )
ustar_1 = m +0*F_filtered
ustar_2 = m/( 1 - F_filtered**2 ) 
ustar_3 = m/( 1 - m ) +0*F_filtered
ustar_4 = m + F_filtered**2
ustar_5 = m - m +F_filtered**2


standard_figure_height = 0.7 * standard_figure_width
fig_size = (standard_figure_width, standard_figure_height)

plt.figure()


plt.plot( F_filtered, uschijf_filtered, label='Kreitner', lw = 3, color = 'black' )
plt.plot( F_filtered, ustar_0, label = r'$ \dfrac{m}{1-m -F^2} $'  )
plt.plot( F_filtered, ustar_2, label = r'$ \dfrac{m}{1-F^2} $'  )
plt.plot( F_filtered, ustar_3, label = r'$ \dfrac{m}{1-m} $'  )
plt.plot( F_filtered, ustar_1, label = r'$ m $'  )
# plt.plot( F_filtered, ustar_4, label = r'$ m+F^2 $'  )
# plt.plot( F_filtered, ustar_5, label = r'$ m-m^2 +F^2 $'  )




plt.xlabel( r'Fr' )
plt.ylabel( r'$\dfrac{U}{V}$' )

plt.ylim(0, 0.4)
plt.legend()
plt.title( f'm = {np.round(m, 3)}' )
plt.savefig('../figures/limites_kreitner-u-F.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2478521152.py:9: RuntimeWarning: divide by zero encountered in divide
#   q = 2/F**2
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2478521152.py:11: RuntimeWarning: invalid value encountered in divide
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2478521152.py:11: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

# %%
import numpy as np
import matplotlib.pyplot as plt

# Définition des valeurs de m
m_values = [0.01, 0.1, 0.3]




# Définition de la grille de valeurs de F
F = np.linspace(0, 1, 1000)


standard_figure_height = 0.7 * standard_figure_width
fig_size = (standard_figure_width, standard_figure_height)

# Création de la figure avec 3 sous-graphiques
fig, axs = plt.subplots(1, 3, figsize=(15, 6), sharex=True, sharey=True)

# Boucle sur les valeurs de m
for i, m in enumerate(m_values):
    q = 2 / F**2
    p = -(1 + q * (1 - m))
    y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))
    
    uschijf = y - 1
    F_filtered = F[~np.isnan(uschijf)]
    uschijf_filtered = uschijf[~np.isnan(uschijf)]
    
    ustar_0 = m / (1 - m - F_filtered**2)
    ustar_1 = m + 0 * F_filtered
    ustar_2 = m / (1 - F_filtered**2) 
    ustar_3 = m / (1 - m) + 0 * F_filtered
    
    axs[i].plot(F_filtered, uschijf_filtered, label='Kreitner', lw=3, color='black')
    axs[i].plot(F_filtered, ustar_0, label=r'$ \dfrac{m}{1-m -F^2} $')
    axs[i].plot(F_filtered, ustar_2, label=r'$ \dfrac{m}{1-F^2} $')
    axs[i].plot(F_filtered, ustar_3, label=r'$ \dfrac{m}{1-m} $')
    axs[i].plot(F_filtered, ustar_1, label=r'$ m $')
    axs[i].set_title(f'm = {m}')
    # axs[i].set_xlim(0, 1.05 * np.max(F_filtered))

    axs[i].set_xlabel(r'Fr')
    axs[i].set_ylabel(r'$\dfrac{U}{V}$')
    axs[i].legend()

plt.tight_layout()
plt.savefig('../figures/limites_kreitner-u-F_subplots.pdf', bbox_inches='tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/3064320667.py:22: RuntimeWarning: divide by zero encountered in divide
#   q = 2 / F**2
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/3064320667.py:24: RuntimeWarning: invalid value encountered in divide
#   y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/3064320667.py:24: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))

# %%
import numpy as np
import matplotlib.pyplot as plt
from config import large_figure_width, large_figure_height, standard_figure_width, standard_figure_height


# Définition des valeurs de m
m_values = [0.3, 0.1, 0.01]

# Définition de la grille de valeurs de F
F = np.linspace(0, 1, 1000)


fig_size = (1.1*large_figure_width, large_figure_height)

fig, ax = plt.subplots(figsize=fig_size)

# Définition des styles de ligne pour ustar_0
linestyles = ['dashdot', '--', '-']

# Boucle sur les valeurs de m
for m, linestyle in zip(m_values, linestyles):
    q = 2 / F**2
    p = -(1 + q * (1 - m))
    y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))
    
    uschijf = y - 1
    F_filtered = F[~np.isnan(uschijf)]
    uschijf_filtered = uschijf[~np.isnan(uschijf)]
    
    ustar_0 = m / (1 - m - F_filtered**2)
    ustar_1 = m + 0 * F_filtered
    ustar_2 = m / (1 - F_filtered**2) 
    ustar_3 = m / (1 - m) + 0 * F_filtered
    
    ax.plot(F_filtered, uschijf_filtered, lw=2, color='black', linestyle=linestyle)
    ax.plot( max(F_filtered), max(uschijf_filtered), 'o', color = 'black' )
    ax.plot(F_filtered, ustar_0, color = 'tab:blue', linestyle=linestyle)
    ax.plot(F_filtered, ustar_2, color = 'orange',linestyle=linestyle)
    ax.plot(F_filtered, ustar_3, color = 'green',linestyle=linestyle)
    ax.plot(F_filtered, ustar_1, color = 'red',linestyle=linestyle)

   
ax.plot(F_filtered, uschijf_filtered, label='KSC', lw=2, color='black')
ax.plot( max(F_filtered), max(uschijf_filtered), 'o', color = 'black' )
# ax.plot(F_filtered, ustar_0, label=r'$ \dfrac{m}{1-m -Fn_{Hm}^2} $', color = 'tab:blue', linestyle=linestyle)
ax.plot(F_filtered, ustar_0, label=r'Kim', color = 'tab:blue', linestyle=linestyle)

# ax.plot(F_filtered, ustar_3, label=r'$ \dfrac{m}{1-m} $', color = 'green',linestyle=linestyle)
ax.plot(F_filtered, ustar_3, label=r'Bossut non-linéaire', color = 'green',linestyle=linestyle)
# ax.plot(F_filtered, ustar_2, label=r'$ \dfrac{m}{1-Fn_{Hm}^2} $', color = 'orange',linestyle=linestyle)
ax.plot(F_filtered, ustar_2, label=r'Tuck', color = 'orange',linestyle=linestyle)
ax.plot(F_filtered, ustar_1, label=r'Bossut linéaire', color = 'red',linestyle=linestyle)
    
ax.text( 0.15, 0.6, s ='m = 0.3' )    
    
ax.text( 0.35, 0.2, 'm = 0.1' )
    
ax.text( 0.7, 0.07, 'm = 0.01' )


# ax.set_title('Courbes pour différentes valeurs de m')
ax.set_xlabel(r'$Fn_{Hm}$')
ax.set_ylabel(r'$\dfrac{u}{V}$', rotation=0)
ax.legend()
plt.tight_layout()
plt.savefig('../figures/limites_kreitner-u-F.pdf', bbox_inches='tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_64867/446956245.py:22: RuntimeWarning: divide by zero encountered in divide
#   q = 2 / F**2
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_64867/446956245.py:24: RuntimeWarning: invalid value encountered in divide
#   y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_64867/446956245.py:24: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))

# %%
import numpy as np

# Les valeurs initiales
F = 0.1
m_values = np.linspace(0, 1, 1000)
q = 2/F**2
p = -( 1+q*(1-m) )
y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

uschijf = y - 1

# Calcul de ustar_1
ustar_1 = m_values

# Trouver la différence de 1% entre ustar_1 et uschijf
index = [0]
diff_percent = 0.2
difference = np.abs(ustar_1 - uschijf)
index = np.argmin(np.abs(difference - diff_percent * ustar_1))

# Valeur de m correspondante
m_1_percent_diff = m_values[index]

print(f"Pour une différence de 1% entre ustar_1 et uschijf, m est environ égal à {m_1_percent_diff:.4f}.")
# Out:
# Pour une différence de 1% entre ustar_1 et uschijf, m est environ égal à 0.6827.
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/4125146621.py:8: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

# %%
import numpy as np
import matplotlib.pyplot as plt

# Les valeurs initiales
F = 0.1
m_values = np.linspace(0, 1, 1000)
q = 2/F**2
p = -( 1+q*(1-m) )
y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

uschijf = y - 1

# Calcul de ustar_1
ustar_1 = m_values

# Calcul de l'erreur entre ustar_1 et uschijf
error = np.abs(ustar_1 - uschijf)/uschijf

# Tracer l'erreur en fonction de m
plt.plot(m_values, error)
plt.xlabel('m')
# plt.yscale('log')
plt.ylim(0, 1)
plt.ylabel('Difference')
plt.title(f'Fr = {F}')


plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/3705789310.py:9: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

# %%
import numpy as np

# Les valeurs initiales
F = 0.1
m_values = np.linspace(0, 1, 1000)
q = 2 / F**2
p = -(1 + q * (1 - m_values))
y = np.sqrt(-4 * p / 3) * np.sin(1 / 3 * np.arcsin(np.sqrt(-27 / 4 * q**2 / p**3)))
uschijf = y - 1

# Calcul de ustar_1
ustar_1 = m_values

# Trouver la différence de 1% entre ustar_1 et uschijf
diff_percent = 0.01
difference = np.abs(ustar_1 - uschijf)/uschijf
index = np.argmin(np.abs(difference - diff_percent ))
print (index)
# Valeur de m correspondante
m_1_percent_diff = m_values[index]

print(f"Pour une différence de 1% entre ustar_1 et uschijf, m est environ égal à {m_1_percent_diff:.4f}.")
# Out:
# 682
# Pour une différence de 1% entre ustar_1 et uschijf, m est environ égal à 0.6827.
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2446698755.py:8: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt(-4 * p / 3) * np.sin(1 / 3 * np.arcsin(np.sqrt(-27 / 4 * q**2 / p**3)))

# %%
import numpy as np
import matplotlib.pyplot as plt


W = 54
w = 54
T = 3
B = 1
h = 4.5
Ac = h*W
Ab = B*T
Hm = Ac/W
m = Ab/Ac


m = np.linspace(0, 1, 1000)
F = 0.1

q = 2/F**2
p = -( 1+q*(1-m) )
y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

uschijf = y -1


ustar_0 = m/( 1 - m -F**2 )
ustar_1 = m +0*F
ustar_2 = m/(1-F**2)
ustar_3 = m/( 1 - m ) +0*F
ustar_4 = m + F**2
ustar_5 = m - m +F**2

plt.figure()


plt.plot( m, uschijf, label='Kreitner', lw = 3, color = 'black' )
plt.plot( m, ustar_0, label = r'$ \dfrac{m}{1-m -F^2} $'  )

plt.plot( m, ustar_2, label = r'$ \dfrac{m}{1-F^2} $'  )
plt.plot( m, ustar_3, label = r'$ \dfrac{m}{1-m} $'  )
plt.plot( m, ustar_1, label = r'$ m $'  )
# plt.plot( m, ustar_4, label = r'$ m+F^2 $'  )
# plt.plot( m, ustar_5, label = r'$ m-m^2 +F^2 $'  )




plt.xlabel( r'm' )
plt.ylabel( r'$\dfrac{U}{V}$' )

plt.ylim(0, 1)
plt.legend()
plt.title( f'Fr = {np.round(F, 3)}' )
plt.savefig('../figures/limites_kreitner-u-m2.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/3565128644.py:21: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/3565128644.py:29: RuntimeWarning: divide by zero encountered in divide
#   ustar_3 = m/( 1 - m ) +0*F

# %%
import numpy as np
import matplotlib.pyplot as plt

# Définition des valeurs de m
F_values = [0.01, 0.1, 0.3]




# Définition de la grille de valeurs de F
m = np.linspace(0, 1, 1000)


standard_figure_height = 0.7 * standard_figure_width
fig_size = (standard_figure_width, standard_figure_height)

# Création de la figure avec 3 sous-graphiques
fig, axs = plt.subplots(1, 3, figsize=(15, 6), sharex=True, sharey=True)

# Boucle sur les valeurs de m
for i, F in enumerate(F_values):
    q = 2 / F**2
    p = -(1 + q * (1 - m))
    y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))
    
    uschijf = y - 1
    m_filtered = m[~np.isnan(uschijf)]
    uschijf_filtered = uschijf[~np.isnan(uschijf)]
     
    
    ustar_0 = m_filtered / (1 - m_filtered - F**2)
    ustar_1 = m_filtered 
    ustar_2 = m_filtered / (1 - F**2) 
    ustar_3 = m_filtered / (1 - m_filtered) 
    
    axs[i].plot(m_filtered, uschijf_filtered, label='Kreitner', lw=3, color='black')
    axs[i].plot(m_filtered, ustar_0, label=r'$ \dfrac{m}{1-m -F^2} $')
    axs[i].plot(m_filtered, ustar_2, label=r'$ \dfrac{m}{1-F^2} $')
    axs[i].plot(m_filtered, ustar_3, label=r'$ \dfrac{m}{1-m} $')
    axs[i].plot(m_filtered, ustar_1, label=r'$ m $')
    axs[i].set_title(f'Fr = {F}')
    axs[i].set_ylim(-0.02, 2)

    axs[i].set_xlabel(r'm')
    axs[i].set_ylabel(r'$\dfrac{U}{V}$')
    axs[i].legend()

plt.tight_layout()
plt.savefig('../figures/limites_kreitner-u-m_subplots.pdf', bbox_inches='tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/3029156181.py:24: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt(-4 * p / 3) * np.sin(1/3 * np.arcsin(np.sqrt(-27/4 * q**2 / p**3)))

# %%
import numpy as np
import matplotlib.pyplot as plt


W = 54
w = 45
T = 3
B = 11
h = 4.5
Ac = h*W
Ab = B*T
Hm = Ac/W
m = Ab/Ac


z = np.linspace(0, 2, 1000)

z = z/Hm


Fc = np.sqrt( ( 2*z*(1-z-m)**2 )/( 1-(1-z-m)**2 ) )

F = np.linspace(min(Fc), max(Fc), 1000)

q = 2/F**2
p = -( 1+q*(1-m) )
y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

zp = 1-m-1/y

zmichell = -m*F**2/(F**2-1)
zmichell2 = -m*F**2/(F**2-1+2*m)
zkim = -m*F**2/(F**2-1+m)

plt.figure()


plt.plot( F, zp, label='Kreitner', lw = 3, color = 'black' )
#plt.plot( Fc, z, '--', label='Schijf', lw = 3, color = 'black' )
plt.plot( F, zmichell, label = r'$ \dfrac{F^2}{1-F^2} $'  )
plt.plot( F, zmichell2, label = r'$ \dfrac{F^2}{1-F^2 - 2 m} $' )
plt.plot( F, zkim, label = '$ \dfrac{F^2}{1-F^2 - m} $' )

plt.plot( F, m*F**2, label = r'$mF^2$' )
plt.xlabel( r'Fr' )
plt.ylabel( r'$\dfrac{z}{h}$' )

plt.title( f'm = {np.round(m, 3)}' )
plt.ylim(0, 0.25)
plt.legend()
plt.savefig('../figures/limites_kreitner-z-F.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2496191569.py:25: RuntimeWarning: divide by zero encountered in divide
#   q = 2/F**2
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/2496191569.py:27: RuntimeWarning: invalid value encountered in divide
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

# %%
import numpy as np
import matplotlib.pyplot as plt


W = 54
w = 45
T = 3
B = 11
h = 4.5
Ac = h*W
Ab = B*T
Hm = Ac/W
m = Ab/Ac


m = np.linspace(0, 1, 1000)
F = 0.15


q = 2/F**2
p = -( 1+q*(1-m) )
y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )

zp = 1-m-1/y

zmichell = -m*F**2/(F**2-1)
zmichell2 = -m*F**2/(F**2-1+2*m)
zkim = -m*F**2/(F**2-1+m)

plt.figure()


plt.plot( m, zp, label='Kreitner', lw = 3, color = 'black' )
plt.plot( m, zmichell2, label = r'$ \dfrac{mF^2}{1-F^2 - 2 m} $' )
#plt.plot( Fc, z, '--', label='Schijf', lw = 3, color = 'black' )
plt.plot( m, zmichell, label = r'$ \dfrac{mF^2}{1-F^2} $'  )

plt.plot( m, zkim, label = '$ \dfrac{mF^2}{1-F^2 - m} $' )

plt.plot( m, m*F**2, label = r'$mF^2$' )
plt.xlabel( r'm' )
plt.ylabel( r'$\dfrac{z}{h}$' )

plt.title( f'Fr = {np.round(F, 3)}' )
plt.ylim(0, 1.05*max(zp))
plt.legend()
plt.savefig('../figures/limites_kreitner-z-m.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# /var/folders/q9/zszppxr51xd4ncd2rhntll7cx7z7yt/T/ipykernel_98497/1466039245.py:22: RuntimeWarning: invalid value encountered in arcsin
#   y = np.sqrt( -4*p/3 )*np.sin( 1/3*np.arcsin( np.sqrt( -27/4*q**2/p**3 ) ) )
